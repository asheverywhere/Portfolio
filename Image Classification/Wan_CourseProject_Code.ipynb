# %%
# example of using a pre-trained model as a classifier for one image
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot as plt

from tensorflow import keras
import tensorflow as tf
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16
from keras.callbacks import EarlyStopping

import os
import time

# %%
#make 'sample' folder
path = 'C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs'
os.chdir(path)
sampFolder = 'sample'
os.makedirs(sampFolder)
#make sub sample folders
path = 'C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\sample'
os.chdir(path)
for i in range(1,11): 
    sampFolder = 'samplecu'+ str(i)
    os.makedirs(sampFolder)
#rename folders
os.rename("samplecu1","c0")
os.rename("samplecu2","c1")
os.rename("samplecu3","c2")
os.rename("samplecu4","c3")
os.rename("samplecu5","c4")
os.rename("samplecu6","c5")
os.rename("samplecu7","c6")
os.rename("samplecu8","c7")
os.rename("samplecu9","c8")
os.rename("samplecu10","c9")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c66c01d64ff2> in <module>()
#       1 #make 'sample' folder
#       2 path = 'C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs'
# ----> 3 os.chdir(path)
#       4 sampFolder = 'sample'
#       5 os.makedirs(sampFolder)
#
# NameError: name 'os' is not defined

# %%
#create sample for each folder from trained to sample
trainPath = 'C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\train'
samplePath = 'C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\sample'

# %%
#Prompting user to enter number of files to select randomly along with directory
source="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\train\\c0"
dest="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\sample\\c0"
no_of_files=int(100)

print("%"*25+"{ Details Of Transfer }"+"%"*25)
print("\n\nList of Files Moved to %s :-"%(dest))

#Using for loop to randomly choose multiple files
for i in range(no_of_files):
    #Variable random_file stores the name of the random file chosen
    random_file=random.choice(os.listdir(source))
    print("%d} %s"%(i+1,random_file))
    source_file="%s\%s"%(source,random_file)
    dest_file=dest
    #"shutil.move" function moves file from one directory to another
    shutil.copy(source_file,dest_file)

print("\n\n"+"$"*33+"[ Files Moved Successfully ]"+"$"*33)

# %%
#Prompting user to enter number of files to select randomly along with directory
source="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\train\\c1"
dest="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\sample\\c1"
no_of_files=int(100)

print("%"*25+"{ Details Of Transfer }"+"%"*25)
print("\n\nList of Files Moved to %s :-"%(dest))

#Using for loop to randomly choose multiple files
for i in range(no_of_files):
    #Variable random_file stores the name of the random file chosen
    random_file=random.choice(os.listdir(source))
    print("%d} %s"%(i+1,random_file))
    source_file="%s\%s"%(source,random_file)
    dest_file=dest
    #"shutil.move" function moves file from one directory to another
    shutil.copy(source_file,dest_file)

print("\n\n"+"$"*33+"[ Files Moved Successfully ]"+"$"*33)

# %%
#Prompting user to enter number of files to select randomly along with directory
source="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\train\\c2"
dest="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\sample\\c2"
no_of_files=int(100)

print("%"*25+"{ Details Of Transfer }"+"%"*25)
print("\n\nList of Files Moved to %s :-"%(dest))

#Using for loop to randomly choose multiple files
for i in range(no_of_files):
    #Variable random_file stores the name of the random file chosen
    random_file=random.choice(os.listdir(source))
    print("%d} %s"%(i+1,random_file))
    source_file="%s\%s"%(source,random_file)
    dest_file=dest
    #"shutil.move" function moves file from one directory to another
    shutil.copy(source_file,dest_file)

print("\n\n"+"$"*33+"[ Files Moved Successfully ]"+"$"*33)

# %%
#Prompting user to enter number of files to select randomly along with directory
source="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\train\\c3"
dest="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\sample\\c3"
no_of_files=int(100)

print("%"*25+"{ Details Of Transfer }"+"%"*25)
print("\n\nList of Files Moved to %s :-"%(dest))

#Using for loop to randomly choose multiple files
for i in range(no_of_files):
    #Variable random_file stores the name of the random file chosen
    random_file=random.choice(os.listdir(source))
    print("%d} %s"%(i+1,random_file))
    source_file="%s\%s"%(source,random_file)
    dest_file=dest
    #"shutil.move" function moves file from one directory to another
    shutil.copy(source_file,dest_file)

print("\n\n"+"$"*33+"[ Files Moved Successfully ]"+"$"*33)

# %%
#Prompting user to enter number of files to select randomly along with directory
source="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\train\\c4"
dest="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\sample\\c4"
no_of_files=int(100)

print("%"*25+"{ Details Of Transfer }"+"%"*25)
print("\n\nList of Files Moved to %s :-"%(dest))

#Using for loop to randomly choose multiple files
for i in range(no_of_files):
    #Variable random_file stores the name of the random file chosen
    random_file=random.choice(os.listdir(source))
    print("%d} %s"%(i+1,random_file))
    source_file="%s\%s"%(source,random_file)
    dest_file=dest
    #"shutil.move" function moves file from one directory to another
    shutil.copy(source_file,dest_file)

print("\n\n"+"$"*33+"[ Files Moved Successfully ]"+"$"*33)

# %%
#Prompting user to enter number of files to select randomly along with directory
source="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\train\\c5"
dest="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\sample\\c5"
no_of_files=int(100)

print("%"*25+"{ Details Of Transfer }"+"%"*25)
print("\n\nList of Files Moved to %s :-"%(dest))

#Using for loop to randomly choose multiple files
for i in range(no_of_files):
    #Variable random_file stores the name of the random file chosen
    random_file=random.choice(os.listdir(source))
    print("%d} %s"%(i+1,random_file))
    source_file="%s\%s"%(source,random_file)
    dest_file=dest
    #"shutil.move" function moves file from one directory to another
    shutil.copy(source_file,dest_file)

print("\n\n"+"$"*33+"[ Files Moved Successfully ]"+"$"*33)

# %%
#Prompting user to enter number of files to select randomly along with directory
source="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\train\\c6"
dest="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\sample\\c6"
no_of_files=int(100)

print("%"*25+"{ Details Of Transfer }"+"%"*25)
print("\n\nList of Files Moved to %s :-"%(dest))

#Using for loop to randomly choose multiple files
for i in range(no_of_files):
    #Variable random_file stores the name of the random file chosen
    random_file=random.choice(os.listdir(source))
    print("%d} %s"%(i+1,random_file))
    source_file="%s\%s"%(source,random_file)
    dest_file=dest
    #"shutil.move" function moves file from one directory to another
    shutil.copy(source_file,dest_file)

print("\n\n"+"$"*33+"[ Files Moved Successfully ]"+"$"*33)

# %%
#Prompting user to enter number of files to select randomly along with directory
source="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\train\\c7"
dest="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\sample\\c7"
no_of_files=int(100)

print("%"*25+"{ Details Of Transfer }"+"%"*25)
print("\n\nList of Files Moved to %s :-"%(dest))

#Using for loop to randomly choose multiple files
for i in range(no_of_files):
    #Variable random_file stores the name of the random file chosen
    random_file=random.choice(os.listdir(source))
    print("%d} %s"%(i+1,random_file))
    source_file="%s\%s"%(source,random_file)
    dest_file=dest
    #"shutil.move" function moves file from one directory to another
    shutil.copy(source_file,dest_file)

print("\n\n"+"$"*33+"[ Files Moved Successfully ]"+"$"*33)

# %%
#Prompting user to enter number of files to select randomly along with directory
source="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\train\\c8"
dest="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\sample\\c8"
no_of_files=int(100)

print("%"*25+"{ Details Of Transfer }"+"%"*25)
print("\n\nList of Files Moved to %s :-"%(dest))

#Using for loop to randomly choose multiple files
for i in range(no_of_files):
    #Variable random_file stores the name of the random file chosen
    random_file=random.choice(os.listdir(source))
    print("%d} %s"%(i+1,random_file))
    source_file="%s\%s"%(source,random_file)
    dest_file=dest
    #"shutil.move" function moves file from one directory to another
    shutil.copy(source_file,dest_file)

print("\n\n"+"$"*33+"[ Files Moved Successfully ]"+"$"*33)

# %%
#Prompting user to enter number of files to select randomly along with directory
source="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\train\\c9"
dest="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\sample\\c9"
no_of_files=int(100)

print("%"*25+"{ Details Of Transfer }"+"%"*25)
print("\n\nList of Files Moved to %s :-"%(dest))

#Using for loop to randomly choose multiple files
for i in range(no_of_files):
    #Variable random_file stores the name of the random file chosen
    random_file=random.choice(os.listdir(source))
    print("%d} %s"%(i+1,random_file))
    source_file="%s\%s"%(source,random_file)
    dest_file=dest
    #"shutil.move" function moves file from one directory to another
    shutil.copy(source_file,dest_file)

print("\n\n"+"$"*33+"[ Files Moved Successfully ]"+"$"*33)

# %%
#Measure time of epochs
import time

start = time.time()

history.fit(X_train, y_train, print_progress=True)

end = time.time()
final_time = end-start
print(final_time)

# %% [markdown]
# Victor's Code

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir resources

# !unzip '/content/drive/MyDrive/data.zip' -d resources

# %%
# For exploratory data analysis and preprocessing the images
import os
import gc
gc.collect()

import numpy as np
from numpy import expand_dims

from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator

# %matplotlib inline
import matplotlib.pyplot as plt

from numpy import asarray
from PIL import Image

# To make a CSV for this training data
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt
import cv2
import random
import pickle

# tensorflow and VGG16
import tensorflow as tf
from tensorflow import keras

import keras.backend as K
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16
from keras.callbacks import EarlyStopping

# for tracking duration of training 
import time

# %%
train_path = "/content/resources/data/train/"
valid_path = "/content/resources/data/valid/"
test_path = "/content/resources/data/test"

# %%
# Setting up the training data function
class_labels = ['c0', 'c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9']

file_list = []
class_list = []

DATADIR = '/content/resources/data/valid'

# The size of the images that the neural network will use
IMG_SIZE = 224

# Checking for all images in the data folder
for category in class_labels:
	path = os.path.join(DATADIR, category)
	for img in os.listdir(path):
		img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)

training_data = []

def create_training_data():
	for category in class_labels:
		path = os.path.join(DATADIR, category)
		class_num = class_labels.index(category)
		for img in os.listdir(path):
			try :
				img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
				new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
				training_data.append([new_array, class_num])
			except Exception as e:
				pass

create_training_data()

# Before training the model, 
# shuffle the dataset to increase the randomness of the sample
random.shuffle(training_data)

X = [] #features
y = [] #labels

for features, label in training_data:
	X.append(features)
	y.append(label)
 
train_df = pd.DataFrame({"img": X, "label": y})

# Normalize the image arrays
train_df['img'] = train_df['img'] / 255

# save to train CSV
train_df.to_csv("/content/validation_driver_data.csv")
train_df.head()
# Out:
#                                                  img  label
# 0  [[0.16470588235294117, 0.1568627450980392, 0.1...      2
# 1  [[0.1607843137254902, 0.1607843137254902, 0.16...      9
# 2  [[0.11372549019607843, 0.10980392156862745, 0....      3
# 3  [[0.1803921568627451, 0.1803921568627451, 0.18...      6
# 4  [[0.17254901960784313, 0.17254901960784313, 0....      0

# %%
class_labels = ['safe driving', 'texting - right', 'talking on the phone - right', 'texting - left', 
                'talking on the phone - left', 'operating the radio', 'drinking', 
                'reaching behind', 'hair and makeup', 'talking to passenger']

def plot_dataset(dataset, num=4):
  # Display examples of the images
  plt.figure(figsize=(20,20))
      
  # plot first few images
  for i in range(num):
      
      # define subplot
      plt.subplot(1,num,i + 1)
      
      # plot raw pixel data
      plt.xticks([])
      plt.yticks([])
      plt.grid(False)
      plt.imshow(dataset['img'][i], cmap=plt.get_cmap('gray'))
      plt.title(class_labels[dataset['label'][i]], fontsize=12)

plot_dataset(train_df, 6)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                    test_size=0.33, 
                                    shuffle = True, 
                                    random_state=42)

# %%
# to prevent the model from overfitting
# stopping when the accuracy is the same for more than one epoch
earlystopping = tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=2)

# importing the VGG16 model
vgg16_model = tf.keras.applications.vgg16.VGG16()

# training the VGG16 model to have a new layer for 10 classes
model = keras.Sequential()
for layer in vgg16_model.layers[:-1]:
    model.add(layer)

for layer in model.layers:
    layer.trainable = False

model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
def plot_train_history(history):
    """
    Plot the validation accuracy and validation loss over epochs
    """
    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
# simplify the class labels to match the folder names
class_labels = ['c0', 'c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9']

# build out function to augment the images
# train and test the model using the validation set
# plot the accuracy and the loss 
def train_model():

  train_batches = ImageDataGenerator(rescale= 1. / 255, shear_range = 0.2, zoom_range = 0.2, horizontal_flip = True)    \
  .flow_from_directory(directory=train_path, target_size=(224,224), classes=class_labels, batch_size=10)

  valid_batches = ImageDataGenerator(rescale= 1. / 255, shear_range = 0.2, zoom_range = 0.2, horizontal_flip = True)    \
  .flow_from_directory(directory=valid_path, target_size=(224,224), classes=class_labels, batch_size=10)

  history = model.fit(x=train_batches,
            steps_per_epoch=len(train_batches),
            validation_data=valid_batches,
            validation_steps=len(valid_batches),
            epochs=20,
            verbose=2,
            callbacks=[earlystopping])
  
  model.save('/content/cnn_model.h5')

  plot_train_history(history)

# %%
start = time.time()

train_model()

# stopwatch
end = time.time()
final_time = end-start
print(f'Total time: {round(final_time, 2)} seconds')
# Out:
# Found 22427 images belonging to 10 classes.
# Found 100 images belonging to 10 classes.
# Epoch 1/20
# 2243/2243 - 396s - loss: 2.0074 - accuracy: 0.3243 - val_loss: 1.4577 - val_accuracy: 0.5200 - 396s/epoch - 176ms/step
# Epoch 2/20
# 2243/2243 - 349s - loss: 1.5162 - accuracy: 0.4833 - val_loss: 1.3481 - val_accuracy: 0.5200 - 349s/epoch - 156ms/step
# Epoch 3/20
# 2243/2243 - 346s - loss: 1.3118 - accuracy: 0.5556 - val_loss: 1.4317 - val_accuracy: 0.5400 - 346s/epoch - 154ms/step
# Epoch 4/20
# 2243/2243 - 345s - loss: 1.1899 - accuracy: 0.6000 - val_loss: 1.0323 - val_accuracy: 0.6400 - 345s/epoch - 154ms/step
# Epoch 5/20
# 2243/2243 - 345s - loss: 1.0917 - accuracy: 0.6310 - val_loss: 0.9086 - val_accuracy: 0.6900 - 345s/epoch - 154ms/step
# Epoch 6/20
# 2243/2243 - 346s - loss: 0.9978 - accuracy: 0.6649 - val_loss: 0.9620 - val_accuracy: 0.6800 - 346s/epoch - 154ms/step
# Epoch 7/20

# %%
model.save('/content/cnn_model.h5')

class_labels = ['c0', 'c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9']

# The size of the images that the neural network will use
IMG_SIZE = 224

# Get the saved model
model = tf.keras.models.load_model("cnn_model.h5")

valid_batches = ImageDataGenerator(rescale= 1. / 255, shear_range = 0.2, zoom_range = 0.2, horizontal_flip = True)    \
  .flow_from_directory(directory=valid_path, target_size=(224,224), classes=class_labels, batch_size=10)

predictions = []

# list out all the images in the test folder 
for category in class_labels:
  path = os.path.join(valid_path, category)
  for img in os.listdir(path):
    img = os.path.join(path, img)
    input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
    p = model.predict(input_img)[0] 
    predictions.append(p)

# Get the predictions based on the probabilities found above
pred = []
for c in predictions:
    x = c.tolist()
    x = x.index(max(x))
    pred.append(x)
    print(x)

print(pred)
# Out:
# Found 100 images belonging to 10 classes.
# WARNING:tensorflow:Model was constructed with shape (None, 224, 224, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_2'), name='input_2', description="created by layer 'input_2'"), but it was called on an input with incompatible shape (None,).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-70cd83d8f587> in <module>()
#      19     img = os.path.join(path, img)
#      20     input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
# ---> 21     p = model.predict(input_img)[0]
#      22     predictions.append(p)
#      23
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
# ...

# %%
class_labels = ['safe driving', 'texting - right', 'talking on the phone - right', 'texting - left', 
                'talking on the phone - left', 'operating the radio', 'drinking', 
                'reaching behind', 'hair and makeup', 'talking to passenger']

# Get the saved model
model = tf.keras.models.load_model("cnn_model.h5")

# Display examples of the images
fig = plt.figure(figsize=(16,16))

actual = []
predictions = []

def plot_predictions(pred, num):
  # plot first few images
  for i in range(num):
      
      # define subplot
      plt.subplot(1,num,1 + i)
      
      # plot raw pixel data
      plt.xticks([])
      plt.yticks([])
      plt.grid(False)
      plt.imshow(X[i], cmap=plt.get_cmap('gray'))
      
      if class_labels[pred[i]] != class_labels[y[i]]:
        plt.title(class_labels[pred[i]], fontsize=28, color='r')
      else:
        plt.title(class_labels[pred[i]], fontsize=28, color='b')

      actual.append(class_labels[y[i]])
      predictions.append(class_labels[pred[i]])

plot_predictions(pred, 5)

# show the table 
df = pd.DataFrame({'actual':actual, 'predictions': predictions})

# show the figure
plt.show()
df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-cbf78fa6fdbc> in <module>()
#      33       predictions.append(class_labels[pred[i]])
#      34
# ---> 35 plot_predictions(pred, 5)
#      36
#      37 # show the table
#
# <ipython-input-31-cbf78fa6fdbc> in plot_predictions(pred, num)
#      25       plt.imshow(X[i], cmap=plt.get_cmap('gray'))
#      26
# ---> 27       if class_labels[pred[i]] != class_labels[y[i]]:
#      28         plt.title(class_labels[pred[i]], fontsize=28, color='r')
#      29       else:
#
# IndexError: list index out of range

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mkdir resources

# !unzip '/content/drive/MyDrive/data.zip' -d resources

# %%
train_path = "/content/resources/data/train/"
valid_path = "/content/resources/data/valid/"
test_path = "/content/resources/data/test"

# %%
import os
import glob 

import numpy as np
import tensorflow as tf
from tensorflow import keras

# Display
from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Put in your folder path with the sample dataset
# I made a separate folder called 'heatmap' with all folders 
# and a small number of photos in each to test it out first

# NOTE: It will overwrite those images with the heatmapped ones

folder_path = '/content/resources/heatmap'

# %%
# Load a premade model
model_builder = keras.applications.xception.Xception
img_size = (299, 299)
preprocess_input = keras.applications.xception.preprocess_input
decode_predictions = keras.applications.xception.decode_predictions

last_conv_layer_name = "block14_sepconv2_act"

# Make model
model = model_builder(weights="imagenet")

# Remove last layer's softmax
model.layers[-1].activation = None
# Out:
# ...
# 91897856/91884032 [==============================] - 0s 0us/step

# %%
def get_img_array(img_path, size):
    # `img` is a PIL image of size 640x480
    img = keras.preprocessing.image.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (640, 480, 3)
    array = keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 640, 480, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
def save_and_display_gradcam(img_path, heatmap, cam_path, alpha=0.4):
    # Load the original image
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)
    
    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)

    # Save the superimposed image
    superimposed_img.save(cam_path)

# %%
def make_heatmap_dataset(folder_path):

    # Get the list of subfolders in the main folder
    subfolder_list = os.listdir(folder_path)

    for folder in subfolder_list: 
        # Get the list of image files in each folder
        file_list = glob.glob(f"/content/resources/heatmap/{folder}/*.jpg")

        for img_path in file_list: 
            # Make the image array
            img_array = preprocess_input(get_img_array(img_path, size=img_size))
            # Make the heatmap layer
            heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)
            # Super-impose the heatmap layer on the image and save
            save_and_display_gradcam(img_path, heatmap, cam_path=img_path)

# %%
make_heatmap_dataset(folder_path)

# %%
start = time.time()

train_model()

# stopwatch
end = time.time()
final_time = end-start
print(f'Total time: {round(final_time, 2)} seconds')
# Out:
# Found 1700 images belonging to 10 classes.
# Found 100 images belonging to 10 classes.
# Epoch 1/20
# 170/170 - 42s - loss: 2.6704 - accuracy: 0.1206 - val_loss: 2.3060 - val_accuracy: 0.2300 - 42s/epoch - 247ms/step
# Epoch 2/20
# 170/170 - 28s - loss: 2.3837 - accuracy: 0.1759 - val_loss: 2.4316 - val_accuracy: 0.1300 - 28s/epoch - 162ms/step
# Epoch 3/20
# 170/170 - 30s - loss: 2.3013 - accuracy: 0.2088 - val_loss: 2.2455 - val_accuracy: 0.2600 - 30s/epoch - 175ms/step
# Epoch 4/20
# 170/170 - 28s - loss: 2.2218 - accuracy: 0.2453 - val_loss: 2.2134 - val_accuracy: 0.2600 - 28s/epoch - 163ms/step
# Epoch 5/20
# 170/170 - 28s - loss: 2.1626 - accuracy: 0.2576 - val_loss: 2.2197 - val_accuracy: 0.3100 - 28s/epoch - 162ms/step
# Epoch 6/20
# 170/170 - 28s - loss: 2.0503 - accuracy: 0.3047 - val_loss: 2.1174 - val_accuracy: 0.3100 - 28s/epoch - 166ms/step
# Epoch 7/20
# 170/170 - 45s - loss: 2.0997 - accuracy: 0.2824 - val_loss: 1.9579 - val_accuracy: 0.3000 - 45s/epoch - 266ms/step
# ...

# %%
model.save('/content/heatmap_cnn_model.h5')

class_labels = ['c0', 'c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9']

# Get the saved model
model = tf.keras.models.load_model("cnn_model.h5")

predictions = []

# list out all the images in the test folder 
for category in class_labels:
		path = os.path.join(valid_path, category)
		class_num = class_labels.index(category)
  
for img in os.listdir(path):
    p = model.predict(img)
    predictions.append(p)

# Get the predictions based on the probabilities found above
pred = []
for c in predictions:
    x = c.tolist()
    x = x.index(max(x))
    pred.append(x)

print(pred)

# %%
class_labels = ['safe driving', 'texting - right', 'talking on the phone - right', 'texting - left', 
                'talking on the phone - left', 'operating the radio', 'drinking', 
                'reaching behind', 'hair and makeup', 'talking to passenger']

# Get the saved model
model = tf.keras.models.load_model("cnn_model.h5")

# Display examples of the images
fig = plt.figure(figsize=(16,16))

actual = []
predictions = []

def plot_predictions(pred, num):
  # plot first few images
  for i in range(num):
      
      # define subplot
      plt.subplot(1,num,1 + i)
      
      # plot raw pixel data
      plt.xticks([])
      plt.yticks([])
      plt.grid(False)
      plt.imshow(X[i], cmap=plt.get_cmap('gray'))
      
      if class_labels[pred[i]] != class_labels[y[i]]:
        plt.title(class_labels[pred[i]], fontsize=28, color='r')
      else:
        plt.title(class_labels[pred[i]], fontsize=28, color='b')

      actual.append(class_labels[y[i]])
      predictions.append(class_labels[pred[i]])

plot_predictions(pred, 5)

# show the table 
df = pd.DataFrame({'actual':actual, 'predictions': predictions})

# show the figure
plt.show()
df

# %% [markdown]
# #Ash's Code

# %%
# for loading/processing the images  
from keras.preprocessing.image import load_img 
from keras.preprocessing.image import img_to_array 
from keras.applications.vgg16 import preprocess_input 

# models 
from keras.applications.vgg16 import VGG16 
from keras.models import Model

# clustering and dimension reduction
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report
from IPython.display import Image, display


# for everything else
import os
import glob 
import cv2
import numpy as np
import matplotlib.pyplot as plt
from random import randint
import pandas as pd
import pickle
import random
import shutil

# %%
#USING REGULAR IMAGES
images = []
labels = []
#sample created previously from Greg's code
folder_path = 'C:\\Users\\Ash\\Desktop\\HW\\PROJECT\\imgs\\sample'

subfolder_list = os.listdir(folder_path)

for folder in subfolder_list: 
        # Get the list of image files in each folder
        file_list = glob.glob(f"C:\\Users\\Ash\\Desktop\\HW\\PROJECT\\imgs\\sample\\{folder}\\*.jpg")
        #Run each images through and resize and change the color of each images
        for img_path in file_list: 
            image = cv2.imread(img_path)
            image = cv2.resize(image, (224, 224))
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            #append images and labels to their respected lists
            images.append(image)
            labels.append(folder)
#print out first 5 to make sure they are right
print(images[:5])
print(labels[:5])

#USING HEATMAPPING IMAGES
images = []
labels = []
folder_path = 'C:\\Users\\Ash\\Desktop\\HW\\PROJECT\\imgs\\sample-heatmap'

subfolder_list = os.listdir(folder_path)

for folder in subfolder_list: 
        # Get the list of image files in each folder
        file_list = glob.glob(f"C:\\Users\\Ash\\Desktop\\HW\\PROJECT\\imgs\\sample-heatmap\\{folder}\\*.jpg")

        for img_path in file_list: 
            image = cv2.imread(img_path)
            image = cv2.resize(image, (224, 224))
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            
            images.append(image)
            labels.append(folder)

print(images[:5])
print(labels[:5])

# %%
#Show random images for each labels
def show_random_images(images, labels, number_of_images_to_show=3):

    for code in list(set(labels)):

        indicies = [i for i, label in enumerate(labels) if label == code]
        random_indicies = [random.choice(indicies) for i in range(number_of_images_to_show)]
        figure, axis = plt.subplots(1, number_of_images_to_show)

        print("{} random images for code {}".format(number_of_images_to_show, code))

        for image in range(number_of_images_to_show):
            axis[image].imshow(images[random_indicies[image]])
        plt.show()

# %%
show_random_images(images, labels)
#normalize the images through numpy
images = np.array(images, dtype=np.float32)
labels = np.array(labels)

images /= 255

# %%
#create the vgg16 model using imagenet weight
vgg16_model = VGG16(include_top=False, weights="imagenet", input_shape=(224,224,3))

# %%
#run the predict and reshape the results
def imgcov_transform(model, raw_images):
    pred = model.predict(raw_images)
    flat = pred.reshape(raw_images.shape[0], -1)
    return flat

# %%
vgg16_output = imgcov_transform(vgg16_model, images)
print("VGG16 flattened output has {} features".format(vgg16_output.shape[1]))

# %%
#create pca model to make running the vgg16 model faster
def create_PCA(data, n_components=None):
    p = PCA(n_components=n_components, random_state=728)
    p.fit(data)
    return p

# %%
vgg16_pca = create_PCA(vgg16_output)

# %%
#plot the pca graph to see what our graph would look like
def pca_plot(pca):
    plt.plot(np.cumsum(pca.explained_variance_ratio_))
    plt.xlabel('number of components')
    plt.ylabel('cumulative explained variance')
    plt.show()

# %%
pca_plot(vgg16_pca)

# %%
#perform transfrom on the vgg16 output so we can use for kmeans model
vgg16_output_pca = vgg16_pca.transform(vgg16_output)

# %%
#create kmeans model and fit it using vgg16 output
kmean_vgg16 = KMeans(n_clusters=10, n_jobs=-1, random_state=728 )
kmean_vgg16.fit(vgg16_output_pca)

# %%
#run kmeans prediction
k_vgg16_pred = kmean_vgg16.predict(vgg16_output_pca)

# %%
#create a confusion matrix of all the labels and its clusters
def cluster_label_count(clusters, labels):
    
    count = {}
    
    # Get unique clusters and labels
    unique_clusters = list(set(clusters))
    unique_labels = list(set(labels))
    
    # Create counter for each cluster/label combination and set it to 0
    for cluster in unique_clusters:
        count[cluster] = {}
        
        for label in unique_labels:
            count[cluster][label] = 0
    
    # Let's count
    for i in range(len(clusters)):
        count[clusters[i]][labels[i]] +=1
    
    cluster_df = pd.DataFrame(count)
    
    return cluster_df

# %%
vgg16_count = cluster_label_count(k_vgg16_pred, labels)
vgg16_count

# %%
#rename the cluster names to the appropriate labels manually
vgg16_cluster_code = ["c2","c6","c8","c4","c1","c3","c5","c7","c9","c0"]
vgg16_pred_codes = [vgg16_cluster_code[x] for x in k_vgg16_pred]
vgg16_count = cluster_label_count(vgg16_pred_codes, labels)
vgg16_count

# %%
#run accuracry score and classification report for the kmeans results
from sklearn.metrics import accuracy_score, f1_score
def print_scores(true, pred):
    acc = accuracy_score(true, pred)
    f1 = f1_score(true, pred, average="macro")
    return "\n\tF1 Score: {0:f}   |   Accuracy: {0:f}".format(f1,acc)

print("KMeans VGG16:", print_scores(labels, vgg16_pred_codes))
print(classification_report(labels, vgg16_pred_codes))

# %%
#change labels to the real words
vgg16_cluster_code = ["talking phone-right", "drinking", "hair and makeup", "talking phone-left", "texting-right", "texting-left", "operating radio", "reaching behind","talking to passenger", "safe"]
vgg16_pred_codes = [vgg16_cluster_code[x] for x in k_vgg16_pred]
vgg16_count = cluster_label_count(vgg16_pred_codes, labels)
vgg16_count

# %%
#show random images based on the clustering results
show_random_images(images, vgg16_pred_codes)

# %%
'''
Greg Random Forest
'''
# Out:
# '\nGreg Random Forest\n'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mkdir data

# !unzip '/content/drive/MyDrive/imgs.zip' -d data
# Out:
# mkdir: cannot create directory ‘data’: File exists
# Archive:  /content/drive/MyDrive/imgs.zip
# replace data/test/img_1.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# n

# %%
import numpy as np 
import matplotlib.pyplot as plt
import glob
import cv2

from keras.models import Model, Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
import os
import seaborn as sns

# %%
#make 'sample' folder for test images

path = 'C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs'
os.chdir(path)
sampFolder = 'sample'
os.makedirs(sampFolder)

# %%
#enter number of files to select randomly along with directory
import random
import shutil

source="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\test"
dest="C:\\Users\\gt_ha\\IST 718\\Group Project\\imgs\\sample"
no_of_files=int(100)

print("%"*25+"{ Details Of Transfer }"+"%"*25)
print("\n\nList of Files Moved to %s :-"%(dest))

#Using for loop to randomly choose multiple files
for i in range(no_of_files):
    #Variable random_file stores the name of the random file chosen
    random_file=random.choice(os.listdir(source))
    print("%d} %s"%(i+1,random_file))
    source_file="%s\%s"%(source,random_file)
    dest_file=dest
    #"shutil.move" function moves file from one directory to another
    shutil.copy(source_file,dest_file)

print("\n\n"+"$"*33+"[ Files Moved Successfully ]"+"$"*33)

# %%
SIZE = 128

train_images = []
train_labels = [] 
for directory_path in glob.glob("/content/data/train/*"):
    label = directory_path.split("\\")[-1]
    print(label)
    for img_path in glob.glob(os.path.join(directory_path, "*.jpg")):
        print(img_path)
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE, SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        train_images.append(img)
        train_labels.append(label)
        
train_images = np.array(train_images)
train_labels = np.array(train_labels)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/data/train/c5/img_74036.jpg
# /content/data/train/c5/img_58231.jpg
# /content/data/train/c5/img_18066.jpg
# /content/data/train/c5/img_44863.jpg
# /content/data/train/c5/img_43152.jpg
# /content/data/train/c5/img_30359.jpg
# /content/data/train/c5/img_34549.jpg
# /content/data/train/c5/img_86149.jpg
# /content/data/train/c5/img_26582.jpg
# /content/data/train/c5/img_4810.jpg
# /content/data/train/c5/img_78695.jpg
# /content/data/train/c5/img_66337.jpg
# /content/data/train/c5/img_86725.jpg
# /content/data/train/c5/img_67163.jpg
# /content/data/train/c5/img_87850.jpg
# /content/data/train/c5/img_68833.jpg
# /content/data/train/c5/img_48441.jpg
# /content/data/train/c5/img_69601.jpg
# /content/data/train/c5/img_21995.jpg
# /content/data/train/c5/img_32438.jpg
# /content/data/train/c5/img_89824.jpg
# /content/data/train/c5/img_68065.jpg
# /content/data/train/c5/img_56230.jpg
# /content/data/train/c5/img_69602.jpg
# ...

# %%
# test sample
import random

class_labels = ['c0', 'c1', 'c2', 'c3',' c4', 'c5', 'c6', 'c7','c8', 'c9']

test_images = []
test_labels = [] 

for directory_path in glob.glob("sample/"):
    for img_path in glob.glob(os.path.join(directory_path, "*.jpg")):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE, SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        random.shuffle(class_labels) #append random class labels for an matched set tot he trained dataset
        label = class_labels[0]
        test_images.append(img)
        test_labels.append(label)
        
test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %%
#Encode labels from text to integers.
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(test_labels)
test_labels_encoded = le.transform(test_labels)
le.fit(train_labels)
train_labels_encoded = le.transform(train_labels)

# %%
#Split data into test and train datasets (already split but assigning to meaningful convention)
x_train, y_train, x_test, y_test = train_images, train_labels_encoded, test_images, test_labels_encoded

# %%
# Normalize pixel values to between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
#One hot encode y values for neural network. 
from keras.utils import to_categorical
y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

# %%
activation = 'sigmoid'

feature_extractor = Sequential()
feature_extractor.add(Conv2D(32, 3, activation = activation, padding = 'same', input_shape = (SIZE, SIZE, 3)))
feature_extractor.add(BatchNormalization())

feature_extractor.add(Conv2D(32, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
feature_extractor.add(BatchNormalization())
feature_extractor.add(MaxPooling2D())

feature_extractor.add(Conv2D(64, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
feature_extractor.add(BatchNormalization())

feature_extractor.add(Conv2D(64, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
feature_extractor.add(BatchNormalization())
feature_extractor.add(MaxPooling2D())

feature_extractor.add(Flatten())

# %%
#Add layers for deep learning prediction
x = feature_extractor.output  
x = Dense(128, activation = activation, kernel_initializer = 'he_uniform')(x)
prediction_layer = Dense(10, activation = 'softmax')(x) #10 used for actual dimension

# %%
# Make a new model combining both feature extractor and x
cnn_model = Model(inputs=feature_extractor.input, outputs=prediction_layer)
cnn_model.compile(optimizer='rmsprop',loss = 'categorical_crossentropy', metrics = ['accuracy'])
print(cnn_model.summary())

# %%
#Train the CNN model
history = cnn_model.fit(x_train, y_train_one_hot, epochs=8, validation_data = (x_test, y_test_one_hot))

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
prediction_NN = cnn_model.predict(x_test)
prediction_NN = np.argmax(prediction_NN, axis=-1)
prediction_NN = le.inverse_transform(prediction_NN)

# %%
#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, prediction_NN)
print(cm)
sns.heatmap(cm, annot=True)

# %%
#Check results on a few select images

n=9  #Select the index of image to be loaded for testing
img = x_test[n]
plt.imshow(img)
input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
prediction = np.argmax(cnn_model.predict(input_img))  #argmax to convert categorical back to original
prediction = le.inverse_transform([prediction])  #Reverse the label encoder to original name
print("The prediction for this image is: ", prediction)
#print("The actual label for this image is: ", test_labels[n]) do not use this as we randomly assigned a label

# %%
#Now, let us use features from convolutional network for RF
X_for_RF = feature_extractor.predict(x_train) #This is out X input to RF

# %%
#RANDOM FOREST
from sklearn.ensemble import RandomForestClassifier
RF_model = RandomForestClassifier(n_estimators = 50, random_state = 42)

# %%
# Train the model on training data
RF_model.fit(X_for_RF, y_train) #For sklearn no one hot encoding

# %%
#Send test data through same feature extractor process
X_test_feature = feature_extractor.predict(x_test)
#Now predict using the trained RF model. 
prediction_RF = RF_model.predict(X_test_feature)
#Inverse le transform to get original label back. 
prediction_RF = le.inverse_transform(prediction_RF)

# %%
#Print overall accuracy
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, prediction_RF))

# %%
#Confusion Matrix - verify accuracy of each class
cm = confusion_matrix(test_labels, prediction_RF)
#print(cm)
sns.heatmap(cm, annot=True)

# %%
#Check results on a few select images
n=9 #Select the index of image to be loaded for testing
img = x_test[n]
plt.imshow(img)
input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
input_img_features=feature_extractor.predict(input_img)
prediction_RF = RF_model.predict(input_img_features)[0] 
prediction_RF = le.inverse_transform([prediction_RF])  #Reverse the label encoder to original name
print("The prediction for this image is: ", prediction_RF)
#print("The actual label for this image is: ", test_labels[n]) do not use this as we randomly assigned a label
